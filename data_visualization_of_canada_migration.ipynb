# %% [markdown]
# <a href="https://colab.research.google.com/github/quadribello/Hamoye/blob/master/data_visualization_of_canada_migration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)

print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df_can.tail()
# Out:
#            Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 190  Immigrants  Foreigners        Viet Nam   935  ...  1942  1723  1731  2112
# 191  Immigrants  Foreigners  Western Sahara   903  ...     0     0     0     0
# 192  Immigrants  Foreigners           Yemen   935  ...   211   160   174   217
# 193  Immigrants  Foreigners          Zambia   903  ...   102    69    46    59
# 194  Immigrants  Foreigners        Zimbabwe   903  ...   494   434   437   407
#
# [5 rows x 43 columns]

# %%
df_can.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df_can.head(2)
# Out:
#         OdName AreaName          RegName  ...  2011  2012  2013
# 0  Afghanistan     Asia    Southern Asia  ...  2203  2635  2004
# 1      Albania   Europe  Southern Europe  ...   539   620   603
#
# [2 rows x 38 columns]

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_can.head()
# Out:
#           Country Continent           Region  ...  2011  2012  2013
# 0     Afghanistan      Asia    Southern Asia  ...  2203  2635  2004
# 1         Albania    Europe  Southern Europe  ...   539   620   603
# 2         Algeria    Africa  Northern Africa  ...  4325  3774  4331
# 3  American Samoa   Oceania        Polynesia  ...     0     0     0
# 4         Andorra    Europe  Southern Europe  ...     0     1     1
#
# [5 rows x 38 columns]

# %%
# adding a total column to sum up the number of immigrant
df_can['Total'] = df_can.sum(axis=1)
df_can.head()
# Out:
#           Country Continent           Region  ...  2012  2013   Total
# 0     Afghanistan      Asia    Southern Asia  ...  2635  2004  117278
# 1         Albania    Europe  Southern Europe  ...   620   603   31398
# 2         Algeria    Africa  Northern Africa  ...  3774  4331  138878
# 3  American Samoa   Oceania        Polynesia  ...     0     0      12
# 4         Andorra    Europe  Southern Europe  ...     1     1      30
#
# [5 rows x 39 columns]

# %%
# checking for null values
df_can.isnull().sum()
# Out:
# Country      0
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
df_can.describe()
# Out:
#                1980          1981  ...          2013         Total
# count    195.000000    195.000000  ...    195.000000  1.950000e+02
# mean     508.394872    566.989744  ...   1320.702564  6.573490e+04
# std     1949.588546   2152.643752  ...   4237.951988  1.835710e+05
# min        0.000000      0.000000  ...      0.000000  2.000000e+00
# 25%        0.000000      0.000000  ...     45.000000  1.904000e+03
# 50%       13.000000     10.000000  ...    213.000000  1.003600e+04
# 75%      251.500000    295.500000  ...    796.000000  4.447900e+04
# max    22045.000000  24796.000000  ...  34129.000000  1.383808e+06
#
# [8 rows x 35 columns]

# %%
df_can
df_can.set_index('Country', inplace=True)
# tip: The opposite of set is reset. So to reset the index, we can use df_can.reset_index()
# optional: to remove the name of the index
df_can.index.name = None
# Out:
#                Continent              Region  ...  2013   Total
# Country                                       ...
# Afghanistan         Asia       Southern Asia  ...  2004  117278
# Albania           Europe     Southern Europe  ...   603   31398
# Algeria           Africa     Northern Africa  ...  4331  138878
# American Samoa   Oceania           Polynesia  ...     0      12
# Andorra           Europe     Southern Europe  ...     1      30
# ...                  ...                 ...  ...   ...     ...
# Viet Nam            Asia  South-Eastern Asia  ...  2112  194292
# Western Sahara    Africa     Northern Africa  ...     0       4
# Yemen               Asia        Western Asia  ...   217    5970
# Zambia            Africa      Eastern Africa  ...    59    3354
# Zimbabwe          Africa      Eastern Africa  ...   407   17196
#
# [195 rows x 38 columns]

# %%
# 1. the full row data (all columns)
print(df_can.loc['Nigeria'])

# alternate methods
print(df_can[df_can.index == 'Nigeria'].T.squeeze())
# Out:
# Continent                Africa
# Region           Western Africa
# DevName      Developing regions
# 1980                         81
# 1981                         60
# 1982                         58
# 1983                         58
# 1984                         78
# 1985                         78
# 1986                        114
# 1987                        149
# 1988                        122
# 1989                        195
# 1990                        181
# 1991                        281
# 1992                        498
# 1993                        428
# 1994                        323
# 1995                        430
# 1996                        531
# 1997                        657
# 1998                        757
# 1999                        966
# 2000                       1182
# 2001                       1426
# 2002                       1403
# 2003                       1064
# 2004                       1518
# 2005                       2236
# ...

# %%
# 2. for year 2013
print(df_can.loc['Nigeria', 2013])
# Out:
# 4172

# %%
# 3. for years 1980 to 1985
print(df_can.loc['Nigeria', [1980, 1981, 1982, 1983, 1984, 1984]])
# Out:
# 1980    81
# 1981    60
# 1982    58
# 1983    58
# 1984    78
# 1984    78
# Name: Nigeria, dtype: object

# %%
# To avoid this ambuigity, let's convert the column names into strings: '1980' to '2013'.
df_can.columns = list(map(str, df_can.columns))
# [print (type(x)) for x in df_can.columns.values] #<-- uncomment to check type of column headers

# %%
# useful for plotting later on
years = list(map(str, range(1980, 2014)))
years

# %%
# 1. create the condition boolean series
condition = df_can['Continent'] == 'Africa'
print(condition)
# Out:
# Country
# Afghanistan       False
# Albania           False
# Algeria            True
# American Samoa    False
# Andorra           False
#                   ...
# Viet Nam          False
# Western Sahara     True
# Yemen             False
# Zambia             True
# Zimbabwe           True
# Name: Continent, Length: 195, dtype: bool

# %%
# 2. pass this condition into the dataFrame
df_can[condition]
# Out:
#                                  Continent           Region  ...  2013   Total
# Country                                                      ...
# Algeria                             Africa  Northern Africa  ...  4331  138878
# Angola                              Africa    Middle Africa  ...    45    4226
# Benin                               Africa   Western Africa  ...   397    5704
# Botswana                            Africa  Southern Africa  ...    76     792
# Burkina Faso                        Africa   Western Africa  ...   322    4086
# Burundi                             Africa   Eastern Africa  ...   480   16220
# Cabo Verde                          Africa   Western Africa  ...     2     402
# Cameroon                            Africa    Middle Africa  ...  2439   32042
# Central African Republic            Africa    Middle Africa  ...   169    1100
# Chad                                Africa    Middle Africa  ...    86    3306
# ...

# %%
# we can pass mutliple criteria in the same line. 
# let's filter for AreaNAme = Asia and RegName = Southern Asia

df_can[(df_can['Continent']=='Africa') & (df_can['Region']=='Western Africa')]

# note: When using 'and' and 'or' operators, pandas requires we use '&' and '|' instead of 'and' and 'or'
# don't forget to enclose the two conditions in parentheses
# Out:
#               Continent          Region             DevName  ...  2012  2013  Total
# Country                                                      ...
# Benin            Africa  Western Africa  Developing regions  ...   391   397   5704
# Burkina Faso     Africa  Western Africa  Developing regions  ...   269   322   4086
# Cabo Verde       Africa  Western Africa  Developing regions  ...     6     2    402
# Côte d'Ivoire    Africa  Western Africa  Developing regions  ...  1024  1170  16582
# Gambia           Africa  Western Africa  Developing regions  ...    18    33   1206
# Ghana            Africa  Western Africa  Developing regions  ...   531   517  52064
# Guinea           Africa  Western Africa  Developing regions  ...   407   463   9782
# Guinea-Bissau    Africa  Western Africa  Developing regions  ...     4     0    166
# Liberia          Africa  Western Africa  Developing regions  ...    58    39   5518
# ...

# %%
# Before we proceed: let's review the changes we have made to our dataframe.
print('data dimensions:', df_can.shape)
print(df_can.columns)
df_can.head(2)
# Out:
# data dimensions: (195, 38)
# Index(['Continent', 'Region', 'DevName', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total'],
#       dtype='object')
#             Continent           Region             DevName  ...  2012  2013   Total
# Country                                                     ...
# Afghanistan      Asia    Southern Asia  Developing regions  ...  2635  2004  117278
# Albania        Europe  Southern Europe   Developed regions  ...   620   603   31398
#
# [2 rows x 38 columns]

# %% [markdown]
# ## Visualizing data using Matplotlib

# %%
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
Nigeria = df_can.loc['Nigeria', years] # passing in years 1980 - 2013 to exclude the 'total' column
Nigeria.head(30)
# Out:
# 1980      81
# 1981      60
# 1982      58
# 1983      58
# 1984      78
# 1985      78
# 1986     114
# 1987     149
# 1988     122
# 1989     195
# 1990     181
# 1991     281
# 1992     498
# 1993     428
# 1994     323
# 1995     430
# 1996     531
# 1997     657
# 1998     757
# 1999     966
# 2000    1182
# 2001    1426
# 2002    1403
# 2003    1064
# 2004    1518
# 2005    2236
# 2006    2594
# 2007    2375
# 2008    2109
# 2009    3156
# Name: Nigeria, dtype: object

# %%
Nigeria.plot()

# %%
Nigeria.index = Nigeria.index.map(int) # let's change the index values of Nigeria to type integer for plotting
Nigeria.plot(kind='line')

plt.title('Immigration from Nigeria')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show() # need this line to show the updates made to the figure

# %%
th just a few lines of code, you were able to quickly identify and visualize the spike in immigration!

Quick note on x and y values in `plt.text(x, y, label)`:
    
     Since the x-axis (years) is type 'integer', we specified x as a year. The y axis (number of immigrants) is type 'integer', so we can just specify the value y = 6000.
    
```python
    plt.text(2000, 6000, '2010 Earthquake') # years stored as type int
```
    If the years were stored as type 'string', we would need to specify x as the index position of the year. Eg 20th index is year 2000 since it is the 20th year with a base year of 1980.
```python
    plt.text(20, 6000, '2010 Earthquake') # years stored as type int
```
    We will cover advanced annotation methods in later modules.

# %%
# Let's compare the number of immigrants from Nigeria and South Africa from 1980 to 2013
data = df_can.loc[['Nigeria', 'South Africa'], years]
data
# Out:
#               1980  1981  1982  1983  1984  ...  2009  2010  2011  2012  2013
# Country                                     ...
# Nigeria         81    60    58    58    78  ...  3156  3906  3103  3443  4172
# South Africa  1026  1118   781   379   271  ...  1188  1238   959  1243  1240
#
# [2 rows x 34 columns]

# %%
data.plot(kind ='line')
That doesn't look right...

# Recall that pandas plots the indices on the x-axis and the columns as individual lines on the y-axis. 
# Since data is a dataframe with the country as the index and years as the columns, we must first transpose the dataframe using transpose() method to swap the row and columns.

# %%
data = data.transpose()
data.head()
# Out:
# Country  Nigeria  South Africa
# 1980          81          1026
# 1981          60          1118
# 1982          58           781
# 1983          58           379
# 1984          78           271

# %%
data.index = data.index.map(int) # let's change the index values of data to type integer for plotting
data.plot(kind='line')
plt.title('Immigrants from Nigeria and South Africa')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
plt.show()

# %%
# let's Compare the trend of top 5 countries that contributed the most to immigration to Canada
df_can.sort_values(by='Total', ascending=False, axis=0, inplace=True)
df_top5 = df_can.head(5)
df_top5
# transpose the dataframe
df_top5 = df_top5[years].transpose()
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='line', figsize=(14, 8)) # pass a tuple (x, y) size
plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
plt.show()
